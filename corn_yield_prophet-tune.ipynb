# %% [markdown]
# # ทำนายผลผลิตข้าวโพด โดยใช้ผลผลิตปีก่อน ๆ ด้วย Prophet
#
# https://facebook.github.io/prophet/docs/quick_start.html

# %%
import numpy as np
import pandas as pd
from fbprophet import Prophet

import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls

from fbprophet.plot import plot_plotly, plot_components_plotly

py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Get data

# %%
yield_file = 'OAE-process/OAE-ผลผลิตข้าวโพดทั้งหมด.xlsx'
df = pd.read_excel(yield_file)

areas = df.groupby(['area']).sum().sort_values(by='value', ascending=False)

# %%
areas[:30]['value'].sum() / areas['value'].sum()
# Out:
# 0.9948643526098973

# %%
def data_in_area(df, area):
    df = df.sort_values(by='date', ascending=False)
    df_area = df[df.area == area].reset_index()
    df_area = df_area[['date', 'value']]
    df_area.columns = ['ds', 'y']
    return df_area

# %%
def resample_year2month(df):
    df = df.set_index('date')
    df.index.name = 'ds'
    return df.resample('MS').asfreq().fillna(method='ffill')

# %%
cost_file = 'OAE-process/OAE-ต้นทุนรวมต่อไร่ข้าวโพดเลี้ยงสัตว์.xlsx'
df_cost = pd.read_excel(cost_file)
df_cost_spl = resample_year2month(df_cost)

precipitation_file = 'OAE-process/OAE-ปริมาณน้ำฝน-ฝนตก.xlsx'
df_precipitation = pd.read_excel(precipitation_file)
df_precipitation_nan = data_in_area(df_precipitation,'Nan').set_index('ds')

rainday_file = 'OAE-process/OAE-ปริมาณน้ำฝน-จำนวนวันฝนตก.xlsx'
df_rainday = pd.read_excel(rainday_file)
df_rainday_nan = data_in_area(df_rainday,'Nan').set_index('ds')

price_file = 'OAE-process/OAE-ราคาข้าวโพดเลี้ยงสัตว์.xlsx'
df_price = pd.read_excel(price_file)
df_price_spl = df_price.set_index('date')

# %% [markdown]
# Util functions

# %%
def add_features(df):
    df = df.join(df_cost_spl['value'], on='ds').rename(columns={'value':'cost'})
    df = df.join(df_precipitation_nan['y'].rename('precipitation'), on='ds')
    df = df.join(df_rainday_nan['y'].rename('rainday'), on='ds')
    df = df.join(df_price_spl['value'], on='ds').rename(columns={'value':'price'})
    return df.sort_values(by='ds', ascending=False).fillna(method='bfill')

def is_harvest_season(ds):
    date = pd.to_datetime(ds)
    return (date.month >= 10 and date.month <= 12)

# %% [markdown]
# # Tuning using Grid Search

# %%
def one_province_predict(Province, **kwags):
    df_yield = data_in_area(df, Province)
    
    df_train, df_test = df_yield[12:], df_yield[:12]
    df_train = add_features(df_train)
    df_test = add_features(df_test)
    df_train['on_season'] = df_train['ds'].apply(is_harvest_season)
    
    model = Prophet(weekly_seasonality=False,
                    daily_seasonality=False,
                    changepoint_prior_scale=kwags['changepoint_prior_scale'],
                    seasonality_prior_scale=kwags['seasonality_prior_scale'], 
                    holidays_prior_scale=kwags['holidays_prior_scale'])
    model.add_seasonality(name='monthly_on_season', 
                          period=30.5, 
                          fourier_order=kwags['fourier_order'], 
                          condition_name='on_season')
    
    for col in ['cost', 'precipitation', 'rainday', 'price']:
        model.add_regressor(col, 
                            prior_scale=kwags['prior_scale'], 
                            mode='multiplicative')

    model.fit(df_train)

    future = model.make_future_dataframe(periods=12, freq="MS")
    future = add_features(future)
    future['on_season'] = future['ds'].apply(is_harvest_season)

    forecast = model.predict(future)
    forecast.yhat.clip(lower=0, inplace=True)
    forecast = forecast.sort_values(by='ds', ascending=False).reset_index().drop(columns=['index'])
    
    # Sanity check that we are evaluating the forecase at the same date
    assert(np.all(forecast[:12]['ds'].to_numpy() == df_test['ds'].to_numpy()))
    # Calculate root mean squared error.
    rmse = np.sqrt(np.mean((forecast[:12]['yhat'].to_numpy() - df_test['y'].to_numpy())**2))
    
    mae = np.mean(np.abs(forecast[:12]['yhat'].to_numpy() - df_test['y'].to_numpy()))
    return rmse, mae

# %%
def all_provinces_predict(**kwags):
    rmses = []
    maes = []
    for province in areas.index[:30]:
        rmse, mae = one_province_predict(Province=province, **kwags)
        rmses.append(rmse)
        maes.append(mae)
    return rmses, maes

# %%
# Python
import itertools
import numpy as np
import pandas as pd

param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'holidays_prior_scale': [5, 10, 20],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
    'fourier_order': [3, 5, 7],
    'prior_scale': [0.1, 1, 5]
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here
province_rmses = []
maes = []  # Store the MAEs for each params here
province_maes = []

# Use cross validation to evaluate all parameters
for params in all_params:
    # %time province_rmse, province_mae = all_provinces_predict(**params)
    province_rmses.append(province_rmse)
    rmses.append(sum(province_rmse))
    province_maes.append(province_mae)
    maes.append(sum(province_mae))
    print(f'Param={params}, \t RMSE={sum(province_rmse)/len(province_rmse):.3f}, MAE={sum(province_mae)/len(province_mae):.3f}')

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
tuning_results['mae'] = maes
print(tuning_results)
# Out:
# CPU times: user 46.5 s, sys: 788 ms, total: 47.3 s
# Wall time: 47.3 s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=16673.077, MAE=13141.966
# CPU times: user 1min 24s, sys: 1.2 s, total: 1min 25s
# Wall time: 1min 25s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=18908.053, MAE=11822.249
# CPU times: user 1min 46s, sys: 752 ms, total: 1min 46s
# Wall time: 1min 46s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=19299.130, MAE=12022.899
# CPU times: user 1min 7s, sys: 712 ms, total: 1min 7s
# Wall time: 1min 7s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=16676.669, MAE=13094.330
# CPU times: user 1min 48s, sys: 776 ms, total: 1min 49s
# Wall time: 1min 49s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=18868.753, MAE=11826.962
# CPU times: user 1min 55s, sys: 748 ms, total: 1min 55s
# Wall time: 1min 55s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=19483.093, MAE=12276.721
# CPU times: user 54.3 s, sys: 680 ms, total: 54.9 s
# Wall time: 54.9 s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=16771.599, MAE=13112.323
# CPU times: user 1min 45s, sys: 748 ms, total: 1min 46s
# Wall time: 1min 46s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=19153.878, MAE=11947.399
# CPU times: user 2min 6s, sys: 796 ms, total: 2min 6s
# Wall time: 2min 6s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=19598.045, MAE=12339.925
# CPU times: user 1min 19s, sys: 748 ms, total: 1min 20s
# Wall time: 1min 20s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=8907.411, MAE=5495.128
# CPU times: user 1min 18s, sys: 724 ms, total: 1min 19s
# Wall time: 1min 19s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=9970.135, MAE=6644.531
# CPU times: user 1min 13s, sys: 732 ms, total: 1min 14s
# Wall time: 1min 14s
# Param={'changepoint_prior_scale': 0.001, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE
s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=16667.436, MAE=13030.358
# CPU times: user 42.6 s, sys: 676 ms, total: 43.3 s
# Wall time: 43.3 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=18760.439, MAE=11805.177
# CPU times: user 41 s, sys: 688 ms, total: 41.7 s
# Wall time: 41.7 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=18802.632, MAE=11803.289
# CPU times: user 41.6 s, sys: 696 ms, total: 42.3 s
# Wall time: 42.3 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=8921.387, MAE=5483.410
# CPU times: user 41.3 s, sys: 764 ms, total: 42 s
# Wall time: 42 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=10136.313, MAE=6678.739
# CPU times: user 40.7 s, sys: 784 ms, total: 41.5 s
# Wall time: 41.5 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=10231.071, MAE=6963.460
# CPU times: user 41.1 s, sys: 664 ms, total: 41.7 s
# Wall time: 41.7 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=9472.325, MAE=5991.337
# CPU times: user 42 s, sys: 716 ms, total: 42.7 s
# Wall time: 42.7 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=11041.588, MAE=7459.586
# CPU times: user 42.5 s, sys: 704 ms, total: 43.2 s
# Wall time: 43.2 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=11037.548, MAE=7547.557
# CPU times: user 42.2 s, sys: 684 ms, total: 42.8 s
# Wall time: 42.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=9811.793, MAE=6081.155
# CPU times: user 42.6 s, sys: 676 ms, total: 43.3 s
# Wall time: 43.3 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=11300.692, MAE=7569.840
# CPU times: user 43.4 s, sys: 796 ms, total: 44.2 s
# Wall time: 44.2 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=10963.290, MAE=7245.085
# CPU times: user 41.3 s, sys: 776 ms, total: 42 s
# Wall time: 42.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=13191.783, MAE=8131.790
# CPU times: user 42.3 s, sys: 784 ms, total: 43.1 s
# Wall time: 43.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=14186.971, MAE=9181.198
# CPU times: user 45 s, sys: 808 ms, total: 45.8 s
# Wall time: 45.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=14607.778, MAE=10044.429
# CPU times: user 42.1 s, sys: 740 ms, total: 42.9 s
# Wall time: 42.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=15014.287, MAE=9064.792
# CPU times: user 44 s, sys: 800 ms, total: 44.8 s
# Wall time: 44.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=15097.181, MAE=9764.411
# CPU times: user 45.1 s, sys: 692 ms, total: 45.8 s
# Wall time: 45.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=15420.889, MAE=10459.213
# CPU times: user 43 s, sys: 700 ms, total: 43.7 s
# Wall time: 43.7 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=14471.697, MAE=9208.447
# CPU times: user 44.6 s, sys: 684 ms, total: 45.3 s
# Wall time: 45.3 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=15026.714, MAE=10033.496
# CPU times: user 44.8 s, sys: 668 ms, total: 45.5 s
# Wall time: 45.5 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=13804.306, MAE=9511.231
# CPU times: user 43.8 s, sys: 704 ms, total: 44.5 s
# Wall time: 44.5 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=17273.389, MAE=10661.852
# CPU times: user 45 s, sys: 692 ms, total: 45.7 s
# Wall time: 45.7 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=16359.851, MAE=10502.583
# CPU times: user 47.2 s, sys: 692 ms, total: 47.9 s
# Wall time: 47.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=16394.284, MAE=11105.744
# CPU times: user 48.1 s, sys: 724 ms, total: 48.8 s
# Wall time: 48.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=23255.344, MAE=13761.173
# CPU times: user 45.2 s, sys: 700 ms, total: 45.9 s
# Wall time: 45.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=15821.417, MAE=10292.081
# CPU times: user 48.1 s, sys: 684 ms, total: 48.8 s
# Wall time: 48.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=16497.825, MAE=11659.511
# CPU times: user 54.1 s, sys: 716 ms, total: 54.8 s
# Wall time: 54.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=47502.354, MAE=24813.014
# CPU times: user 47.8 s, sys: 684 ms, total: 48.5 s
# Wall time: 48.5 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=17764.893, MAE=11412.703
# CPU times: user 52.1 s, sys: 712 ms, total: 52.9 s
# Wall time: 52.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 5, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=13808.867, MAE=9465.954
# CPU times: user 38.4 s, sys: 672 ms, total: 39.1 s
# Wall time: 39.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=16573.926, MAE=13051.206
# CPU times: user 39.5 s, sys: 712 ms, total: 40.2 s
# Wall time: 40.2 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=18758.817, MAE=11795.360
# CPU times: user 40.4 s, sys: 684 ms, total: 41.1 s
# Wall time: 41.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=18832.943, MAE=11756.126
# CPU times: user 39.2 s, sys: 652 ms, total: 39.8 s
# Wall time: 39.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=16574.581, MAE=13005.300
# CPU times: user 42.7 s, sys: 692 ms, total: 43.4 s
# Wall time: 43.4 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=18701.502, MAE=11757.487
# CPU times: user 40.6 s, sys: 668 ms, total: 41.3 s
# Wall time: 41.3 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=18738.753, MAE=11764.378
# CPU times: user 39.8 s, sys: 668 ms, total: 40.5 s
# Wall time: 40.5 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=16667.436, MAE=13030.358
# CPU times: user 42.3 s, sys: 684 ms, total: 43 s
# Wall time: 43 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=18760.439, MAE=11805.177
# CPU times: user 40.9 s, sys: 692 ms, total: 41.6 s
# Wall time: 41.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=18802.632, MAE=11803.289
# CPU times: user 41.4 s, sys: 684 ms, total: 42.1 s
# Wall time: 42.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=8921.387, MAE=5483.410
# CPU times: user 41.4 s, sys: 652 ms, total: 42.1 s
# Wall time: 42.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=10136.313, MAE=6678.739
# CPU times: user 40.9 s, sys: 700 ms, total: 41.6 s
# Wall time: 41.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=10231.071, MAE=6963.460
# CPU times: user 41.2 s, sys: 740 ms, total: 41.9 s
# Wall time: 41.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=9472.325, MAE=5991.337
# CPU times: user 41.9 s, sys: 712 ms, total: 42.6 s
# Wall time: 42.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=11041.588, MAE=7459.586
# CPU times: user 42.4 s, sys: 708 ms, total: 43.1 s
# Wall time: 43.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=11037.548, MAE=7547.557
# CPU times: user 41.9 s, sys: 696 ms, total: 42.6 s
# Wall time: 42.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=9811.793, MAE=6081.155
# CPU times: user 42.4 s, sys: 684 ms, total: 43.1 s
# Wall time: 43.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=11300.692, MAE=7569.840
# CPU times: user 43.4 s, sys: 664 ms, total: 44.1 s
# Wall time: 44.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=10963.290, MAE=7245.085
# CPU times: user 41.2 s, sys: 688 ms, total: 41.9 s
# Wall time: 41.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=13191.783, MAE=8131.790
# CPU times: user 41.9 s, sys: 672 ms, total: 42.5 s
# Wall time: 42.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=14186.971, MAE=9181.198
# CPU times: user 44.2 s, sys: 708 ms, total: 44.9 s
# Wall time: 44.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=14607.778, MAE=10044.429
# CPU times: user 42 s, sys: 672 ms, total: 42.7 s
# Wall time: 42.7 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=15014.287, MAE=9064.792
# CPU times: user 43.5 s, sys: 664 ms, total: 44.2 s
# Wall time: 44.2 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=15097.181, MAE=9764.411
# CPU times: user 45 s, sys: 724 ms, total: 45.7 s
# Wall time: 45.7 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=15420.889, MAE=10459.213
# CPU times: user 43.1 s, sys: 696 ms, total: 43.7 s
# Wall time: 43.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=14471.697, MAE=9208.447
# CPU times: user 45.1 s, sys: 688 ms, total: 45.8 s
# Wall time: 45.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=15026.714, MAE=10033.496
# CPU times: user 44.8 s, sys: 672 ms, total: 45.5 s
# Wall time: 45.5 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=13804.306, MAE=9511.231
# CPU times: user 43.4 s, sys: 700 ms, total: 44.1 s
# Wall time: 44.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=17273.389, MAE=10661.852
# CPU times: user 44.8 s, sys: 676 ms, total: 45.5 s
# Wall time: 45.5 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=16359.851, MAE=10502.583
# CPU times: user 46.9 s, sys: 692 ms, total: 47.6 s
# Wall time: 47.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=16394.284, MAE=11105.744
# CPU times: user 47.4 s, sys: 676 ms, total: 48.1 s
# Wall time: 48.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=23255.344, MAE=13761.173
# CPU times: user 44.6 s, sys: 692 ms, total: 45.3 s
# Wall time: 45.3 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=15821.417, MAE=10292.081
# CPU times: user 47.3 s, sys: 708 ms, total: 48 s
# Wall time: 48 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=16497.825, MAE=11659.511
# CPU times: user 53.6 s, sys: 704 ms, total: 54.3 s
# Wall time: 54.4 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=47502.354, MAE=24813.014
# CPU times: user 47.5 s, sys: 752 ms, total: 48.2 s
# Wall time: 48.3 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=17764.893, MAE=11412.703
# CPU times: user 51.7 s, sys: 704 ms, total: 52.4 s
# Wall time: 52.4 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=13808.867, MAE=9465.954
# CPU times: user 38.1 s, sys: 668 ms, total: 38.8 s
# Wall time: 38.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=16573.926, MAE=13051.206
# CPU times: user 39.9 s, sys: 715 ms, total: 40.6 s
# Wall time: 40.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=18758.817, MAE=11795.360
# CPU times: user 40.5 s, sys: 855 ms, total: 41.3 s
# Wall time: 41.4 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=18832.943, MAE=11756.126
# CPU times: user 39.4 s, sys: 695 ms, total: 40.1 s
# Wall time: 40.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=16574.581, MAE=13005.300
# CPU times: user 42.6 s, sys: 768 ms, total: 43.3 s
# Wall time: 43.4 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=18701.502, MAE=11757.487
# CPU times: user 40.3 s, sys: 672 ms, total: 41 s
# Wall time: 41 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=18738.753, MAE=11764.378
# CPU times: user 39.4 s, sys: 656 ms, total: 40.1 s
# Wall time: 40.1 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=16667.436, MAE=13030.358
# CPU times: user 42 s, sys: 716 ms, total: 42.7 s
# Wall time: 42.8 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=18760.439, MAE=11805.177
# CPU times: user 40.8 s, sys: 696 ms, total: 41.5 s
# Wall time: 41.5 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=18802.632, MAE=11803.289
# CPU times: user 41.3 s, sys: 684 ms, total: 42 s
# Wall time: 42 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=8921.387, MAE=5483.410
# CPU times: user 41.2 s, sys: 696 ms, total: 41.9 s
# Wall time: 41.9 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=10136.313, MAE=6678.739
# CPU times: user 41 s, sys: 688 ms, total: 41.7 s
# Wall time: 41.7 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=10231.071, MAE=6963.460
# CPU times: user 41.2 s, sys: 696 ms, total: 41.9 s
# Wall time: 42 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=9472.325, MAE=5991.337
# CPU times: user 41.9 s, sys: 688 ms, total: 42.6 s
# Wall time: 42.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=11041.588, MAE=7459.586
# CPU times: user 42.2 s, sys: 704 ms, total: 42.9 s
# Wall time: 43 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=11037.548, MAE=7547.557
# CPU times: user 41.9 s, sys: 684 ms, total: 42.6 s
# Wall time: 42.6 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=9811.793, MAE=6081.155
# CPU times: user 42.3 s, sys: 692 ms, total: 43 s
# Wall time: 43 s
# Param={'changepoint_prior_scale': 0.01, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=11300.692, MAE=7569.840
# CPU times: user 43.8 s, sys: 704 ms, total: 44.5 s
# Wall time: 44.5 s
# ...
# CPU times: user 6min 51s, sys: 1.52 s, total: 6min 52s
# Wall time: 6min 52s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=15771.004, MAE=11370.056
# CPU times: user 55.2 s, sys: 800 ms, total: 56 s
# Wall time: 56.1 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=10285.536, MAE=6590.828
# CPU times: user 3min 15s, sys: 912 ms, total: 3min 16s
# Wall time: 3min 16s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=14404.064, MAE=9386.735
# CPU times: user 7min 26s, sys: 1.64 s, total: 7min 28s
# Wall time: 7min 28s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=18674.584, MAE=13191.519
# CPU times: user 6min 9s, sys: 1.18 s, total: 6min 10s
# Wall time: 6min 10s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=17893.511, MAE=12306.527
# CPU times: user 10min 49s, sys: 1.61 s, total: 10min 51s
# Wall time: 10min 50s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=24927.878, MAE=16572.533
# CPU times: user 14min 32s, sys: 2.56 s, total: 14min 34s
# Wall time: 14min 33s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=31782.535, MAE=23296.752
# CPU times: user 6min 2s, sys: 1.14 s, total: 6min 3s
# Wall time: 6min 2s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=18467.832, MAE=11906.301
# CPU times: user 11min 14s, sys: 1.51 s, total: 11min 15s
# Wall time: 11min 15s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=37457.784, MAE=26732.053
# CPU times: user 16min 18s, sys: 2.67 s, total: 16min 20s
# Wall time: 16min 19s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=29522.616, MAE=21442.319
# CPU times: user 6min 39s, sys: 1.27 s, total: 6min 40s
# Wall time: 6min 39s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=17572.736, MAE=11750.573
# CPU times: user 11min 35s, sys: 1.88 s, total: 11min 37s
# Wall time: 11min 36s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=34714.051, MAE=24471.796
# CPU times: user 21min 23s, sys: 2.4 s, total: 21min 25s
# Wall time: 21min 24s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=31451.027, MAE=23018.984
# CPU times: user 4min 48s, sys: 1.05 s, total: 4min 49s
# Wall time: 4min 49s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=22007.840, MAE=14306.067
# CPU times: user 12min 4s, sys: 2.52 s, total: 12min 6s
# Wall time: 12min 6s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=37080.341, MAE=26131.804
# CPU times: user 14min 4s, sys: 2.99 s, total: 14min 7s
# Wall time: 14min 6s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=31366.325, MAE=21590.682
# CPU times: user 6min 1s, sys: 1.23 s, total: 6min 2s
# Wall time: 6min 1s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=24744.100, MAE=15061.492
# CPU times: user 10min 22s, sys: 1.85 s, total: 10min 23s
# Wall time: 10min 23s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=38772.411, MAE=27036.526
# CPU times: user 17min 1s, sys: 2.26 s, total: 17min 3s
# Wall time: 17min 2s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=77614.855, MAE=46266.677
# CPU times: user 7min 29s, sys: 1.34 s, total: 7min 31s
# Wall time: 7min 30s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=57759.585, MAE=29826.935
# CPU times: user 13min 33s, sys: 1.64 s, total: 13min 34s
# Wall time: 13min 33s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=62683.030, MAE=39450.782
# CPU times: user 19min 18s, sys: 2.24 s, total: 19min 20s
# Wall time: 19min 19s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 10, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=36599.752, MAE=23269.366
# CPU times: user 42.6 s, sys: 688 ms, total: 43.3 s
# Wall time: 43.3 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=16607.192, MAE=12851.605
# CPU times: user 48.5 s, sys: 796 ms, total: 49.3 s
# Wall time: 49.3 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=17725.992, MAE=12833.523
# CPU times: user 48.4 s, sys: 720 ms, total: 49.1 s
# Wall time: 49.2 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=18337.457, MAE=13193.184
# CPU times: user 43.5 s, sys: 808 ms, total: 44.3 s
# Wall time: 44.3 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=16623.327, MAE=12814.914
# CPU times: user 49.9 s, sys: 704 ms, total: 50.6 s
# Wall time: 50.6 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=17842.341, MAE=13044.762
# CPU times: user 50.9 s, sys: 676 ms, total: 51.6 s
# Wall time: 51.6 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=18861.671, MAE=13772.225
# CPU times: user 45.6 s, sys: 684 ms, total: 46.3 s
# Wall time: 46.3 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=16722.807, MAE=12871.169
# CPU times: user 50.1 s, sys: 716 ms, total: 50.8 s
# Wall time: 50.9 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=18071.134, MAE=13317.376
# CPU times: user 51.9 s, sys: 712 ms, total: 52.6 s
# Wall time: 52.7 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.01, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=19006.766, MAE=13972.723
# CPU times: user 49.4 s, sys: 704 ms, total: 50.1 s
# Wall time: 50.1 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=9026.771, MAE=5711.574
# CPU times: user 2min 10s, sys: 836 ms, total: 2min 11s
# Wall time: 2min 11s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=11905.788, MAE=7975.961
# CPU times: user 5min 28s, sys: 1.15 s, total: 5min 29s
# Wall time: 5min 29s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=15085.695, MAE=10482.178
# CPU times: user 51.8 s, sys: 716 ms, total: 52.5 s
# Wall time: 52.5 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=9837.812, MAE=6373.291
# CPU times: user 1min 36s, sys: 748 ms, total: 1min 37s
# Wall time: 1min 37s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=12634.630, MAE=8780.658
# CPU times: user 6min 45s, sys: 1.49 s, total: 6min 47s
# Wall time: 6min 46s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=15771.004, MAE=11370.056
# CPU times: user 55.4 s, sys: 684 ms, total: 56.1 s
# Wall time: 56.1 s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=10285.536, MAE=6590.828
# CPU times: user 3min 14s, sys: 876 ms, total: 3min 15s
# Wall time: 3min 14s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=14404.064, MAE=9386.735
# CPU times: user 7min 28s, sys: 1.3 s, total: 7min 29s
# Wall time: 7min 29s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 0.1, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=18674.584, MAE=13191.519
# CPU times: user 6min 6s, sys: 1.2 s, total: 6min 7s
# Wall time: 6min 7s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=17893.511, MAE=12306.527
# CPU times: user 10min 51s, sys: 1.59 s, total: 10min 52s
# Wall time: 10min 51s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=24927.878, MAE=16572.533
# CPU times: user 14min 49s, sys: 2.6 s, total: 14min 52s
# Wall time: 14min 51s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=31782.535, MAE=23296.752
# CPU times: user 6min 2s, sys: 1.21 s, total: 6min 3s
# Wall time: 6min 3s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=18467.832, MAE=11906.301
# CPU times: user 11min 12s, sys: 2.01 s, total: 11min 14s
# Wall time: 11min 13s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=37457.784, MAE=26732.053
# CPU times: user 16min 31s, sys: 2.3 s, total: 16min 33s
# Wall time: 16min 32s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=29522.616, MAE=21442.319
# CPU times: user 6min 49s, sys: 1.49 s, total: 6min 50s
# Wall time: 6min 50s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=17572.736, MAE=11750.573
# CPU times: user 11min 42s, sys: 1.83 s, total: 11min 44s
# Wall time: 11min 44s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=34714.051, MAE=24471.796
# CPU times: user 21min 39s, sys: 3.02 s, total: 21min 42s
# Wall time: 21min 41s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 1.0, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=31451.027, MAE=23018.984
# CPU times: user 4min 48s, sys: 1.05 s, total: 4min 49s
# Wall time: 4min 48s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 0.1}, 	 RMSE=22007.840, MAE=14306.067
# CPU times: user 12min 4s, sys: 2.72 s, total: 12min 6s
# Wall time: 12min 6s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 1}, 	 RMSE=37080.341, MAE=26131.804
# CPU times: user 13min 57s, sys: 2.04 s, total: 13min 59s
# Wall time: 13min 58s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 3, 'prior_scale': 5}, 	 RMSE=31366.325, MAE=21590.682
# CPU times: user 6min, sys: 1.17 s, total: 6min 2s
# Wall time: 6min 1s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 0.1}, 	 RMSE=24744.100, MAE=15061.492
# CPU times: user 10min 27s, sys: 1.93 s, total: 10min 29s
# Wall time: 10min 28s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 1}, 	 RMSE=38772.411, MAE=27036.526
# CPU times: user 17min 5s, sys: 2.49 s, total: 17min 8s
# Wall time: 17min 7s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 5, 'prior_scale': 5}, 	 RMSE=77614.855, MAE=46266.677
# CPU times: user 7min 23s, sys: 1.31 s, total: 7min 25s
# Wall time: 7min 24s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 0.1}, 	 RMSE=57759.585, MAE=29826.935
# CPU times: user 13min 28s, sys: 2.06 s, total: 13min 30s
# Wall time: 13min 29s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 1}, 	 RMSE=62683.030, MAE=39450.782
# CPU times: user 19min 10s, sys: 3.02 s, total: 19min 13s
# Wall time: 19min 12s
# Param={'changepoint_prior_scale': 0.5, 'holidays_prior_scale': 20, 'seasonality_prior_scale': 10.0, 'fourier_order': 7, 'prior_scale': 5}, 	 RMSE=36599.752, MAE=23269.366
#      changepoint_prior_scale  holidays_prior_scale  seasonality_prior_scale  \
# 0                      0.001                     5                     0.01
# 1                      0.001                     5                     0.01
# 2                      0.001                     5                     0.01
# 3                      0.001                     5                     0.01
# 4                      0.001                     5                     0.01
# ..                       ...                   ...                      ...
# 427                    0.500                    20                    10.00
# 428                    0.500                    20                    10.00
# 429                    0.500                    20                    10.00
# 430                    0.500                    20                    10.00
# 431                    0.500                    20                    10.00
#
#      fourier_order  prior_scale          rmse           mae
# 0                3          0.1  5.001923e+05  3.942590e+05
# 1                3          1.0  5.672416e+05  3.546675e+05
# 2                3          5.0  5.789739e+05  3.606870e+05
# 3                5          0.1  5.003001e+05  3.928299e+05
# 4                5          1.0  5.660626e+05  3.548089e+05
# ..             ...          ...           ...           ...
# 427              5          1.0  1.163172e+06  8.110958e+05
# 428              5          5.0  2.328446e+06  1.388000e+06
# 429              7          0.1  1.732788e+06  8.948081e+05
# 430              7          1.0  1.880491e+06  1.183523e+06
# 431              7          5.0  1.097993e+06  6.980810e+05
#
# [432 rows x 7 columns]

# %%
tuning_results.to_csv('corn_yield_prophet-tuning_results.csv')
